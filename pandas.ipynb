# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#       --------------------------------------- 0.2/10.5 MB 3.5 MB/s eta 0:00:03
#      - -------------------------------------- 0.5/10.5 MB 4.7 MB/s eta 0:00:03
#      --- ------------------------------------ 0.9/10.5 MB 6.7 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.3/10.5 MB 6.8 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.5/10.5 MB 7.0 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.5/10.5 MB 7.0 MB/s eta 0:00:02
#      ------ --------------------------------- 1.6/10.5 MB 4.9 MB/s eta 0:00:02
#      ------- -------------------------------- 2.1/10.5 MB 5.5 MB/s eta 0:00:02
#      --------- ------------------------------ 2.6/10.5 MB 6.4 MB/s eta 0:00:02
#      ------------ --------------------------- 3.2/10.5 MB 6.9 MB/s eta 0:00:02
# ...

# %%
import pandas

# %%
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv("WHO-COVID-19-global-data.csv")

# %%
df
# Out:
#       Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0        2020-01-03            AF  Afghanistan        EMRO           0
# 1        2020-01-04            AF  Afghanistan        EMRO           0
# 2        2020-01-05            AF  Afghanistan        EMRO           0
# 3        2020-01-06            AF  Afghanistan        EMRO           0
# 4        2020-01-07            AF  Afghanistan        EMRO           0
# ...             ...           ...          ...         ...         ...
# 71793    2020-10-29            ZW     Zimbabwe        AFRO           5
# 71794    2020-10-30            ZW     Zimbabwe        AFRO           1
# 71795    2020-10-31            ZW     Zimbabwe        AFRO          41
# 71796    2020-11-01            ZW     Zimbabwe        AFRO           5
# 71797    2020-11-02            ZW     Zimbabwe        AFRO           7
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=71798, step=1)

# %%
df.columns
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
df.columns = [c.strip() for c in df.columns]

# %%
df2 = pandas.read_csv("WHO-COVID-19-global-data.csv",
                     skipinitialspace=True,
                     index_col=0,
                     date_format="%Y-%m-%d")

# %%
df2
# Out:
#               Country_code      Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              AF  Afghanistan       EMRO          0
# 2020-01-04              AF  Afghanistan       EMRO          0
# 2020-01-05              AF  Afghanistan       EMRO          0
# 2020-01-06              AF  Afghanistan       EMRO          0
# 2020-01-07              AF  Afghanistan       EMRO          0
# ...                    ...          ...        ...        ...
# 2020-10-29              ZW     Zimbabwe       AFRO          5
# 2020-10-30              ZW     Zimbabwe       AFRO          1
# 2020-10-31              ZW     Zimbabwe       AFRO         41
# 2020-11-01              ZW     Zimbabwe       AFRO          5
# 2020-11-02              ZW     Zimbabwe       AFRO          7
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-01-03                    0           0                  0
# 2020-01-04                    0           0                  0
# ...

# %%
df2.index
# Out:
# DatetimeIndex(['2020-01-03', '2020-01-04', '2020-01-05', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-11', '2020-01-12',
#                ...
#                '2020-10-24', '2020-10-25', '2020-10-26', '2020-10-27',
#                '2020-10-28', '2020-10-29', '2020-10-30', '2020-10-31',
#                '2020-11-01', '2020-11-02'],
#               dtype='datetime64[ns]', name='Date_reported', length=71798, freq=None)

# %%
df['Date_reported']
# Out:
# 0        2020-01-03
# 1        2020-01-04
# 2        2020-01-05
# 3        2020-01-06
# 4        2020-01-07
#             ...
# 71793    2020-10-29
# 71794    2020-10-30
# 71795    2020-10-31
# 71796    2020-11-01
# 71797    2020-11-02
# Name: Date_reported, Length: 71798, dtype: object

# %%
us = df2[df2['Country_code'] == "US"]

# %%
us
# Out:
#               Country_code                   Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              US  United States of America       AMRO          0
# 2020-01-04              US  United States of America       AMRO          0
# 2020-01-05              US  United States of America       AMRO          0
# 2020-01-06              US  United States of America       AMRO          0
# 2020-01-07              US  United States of America       AMRO          0
# ...                    ...                       ...        ...        ...
# 2020-10-30              US  United States of America       AMRO      80384
# 2020-10-31              US  United States of America       AMRO      89048
# 2020-11-01              US  United States of America       AMRO      99356
# 2020-11-02              US  United States of America       AMRO      80379
# 2020-11-03              US  United States of America       AMRO      75888
#
# ...

# %%
us.plot()
# Out:
# <Axes: xlabel='Date_reported'>

# %%
uk = df2[df2['Country_code'] == 'GB']

# %%
uk
# Out:
#               Country_code             Country WHO_region  New_cases  \
# Date_reported
# 2020-01-03              GB  The United Kingdom       EURO          0
# 2020-01-04              GB  The United Kingdom       EURO          0
# 2020-01-05              GB  The United Kingdom       EURO          0
# 2020-01-06              GB  The United Kingdom       EURO          0
# 2020-01-07              GB  The United Kingdom       EURO          0
# ...                    ...                 ...        ...        ...
# 2020-10-29              GB  The United Kingdom       EURO      24700
# 2020-10-30              GB  The United Kingdom       EURO      23065
# 2020-10-31              GB  The United Kingdom       EURO      24405
# 2020-11-01              GB  The United Kingdom       EURO      21915
# 2020-11-02              GB  The United Kingdom       EURO      23254
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# ...

# %%
pandas.merge?
# Out:
# Signature:
# pandas.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | None' = None,
#     left_on: 'IndexLabel | None' = None,
#     right_on: 'IndexLabel | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# When performing a cross merge, no column specifications to merge on are
# allowed.
#
# ...

# %%
merged = pandas.merge(us, uk, on="Date_reported", suffixes=["_US", "_UK"])

# %%
merged
# Out:
#               Country_code_US                Country_US WHO_region_US  \
# Date_reported
# 2020-01-03                 US  United States of America          AMRO
# 2020-01-04                 US  United States of America          AMRO
# 2020-01-05                 US  United States of America          AMRO
# 2020-01-06                 US  United States of America          AMRO
# 2020-01-07                 US  United States of America          AMRO
# ...                       ...                       ...           ...
# 2020-10-29                 US  United States of America          AMRO
# 2020-10-30                 US  United States of America          AMRO
# 2020-10-31                 US  United States of America          AMRO
# 2020-11-01                 US  United States of America          AMRO
# 2020-11-02                 US  United States of America          AMRO
#
#                New_cases_US  Cumulative_cases_US  New_deaths_US  \
# Date_reported
# ...

# %%
merged.plot()
# Out:
# <Axes: xlabel='Date_reported'>

# %%
merged.plot.scatter(x="New_cases_US", y="New_cases_UK")
# Out:
# <Axes: xlabel='New_cases_US', ylabel='New_cases_UK'>

# %%
axis = merged.plot.scatter(x="New_cases_US", y="New_cases_UK")
figure = axis.get_figure()
figure.savefig("usuk.png", dpi=3000)
